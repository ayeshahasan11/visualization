# %%
# import necessary libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests

# generate random data
np.random.seed(613)

x = np.arange(50)
y1 = np.random.randint(0, 100,50)
y2 = np.random.randint(0, 100,50)

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y1, 
    color='blue',
    label='Person 1')
ax.plot(x,y2, 
    color='red',
    label='Person 2')
ax.legend(loc='lower right', #specify legend location
    frameon = True, #add frame around the legend
    fontsize = 12, #change font size
    ncol = 2, #specify number of columns
    shadow = True)
fig.show()
# Out:
# C:\Users\Localadmin\AppData\Local\Temp\ipykernel_32204\3685413233.py:13: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y1, label = "Person 1")
ax.plot(x,y2, label = "Person 2")
ax.legend(loc='upper left',
    bbox_to_anchor =(1, 1))
fig.show()
# Out:
# C:\Users\Localadmin\AppData\Local\Temp\ipykernel_32204\1898960328.py:6: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y1, label = "Person 1")
ax.plot(x,y2, label = "Person 2")
ax.legend(loc='upper right',
    bbox_to_anchor =(0.5, 0.5))
fig.show()
# Out:
# C:\Users\Localadmin\AppData\Local\Temp\ipykernel_32204\3243563486.py:6: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
# Text annotation example
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')

ax.text(10, 95,                 # text is placed at coordinates (10, 95)
    "This value is important!",
    ha='center',                ##alignment of text
    color = 'red',              ##modify font colour
    size = 20,                  ##modify font size
    font = 'Times New Roman') 
fig.show() # display the figure if not using an interactive environment
# Out:
# C:\Users\Localadmin\AppData\Local\Temp\ipykernel_32204\2820063906.py:12: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show() # display the figure if not using an interactive environment

# %%
# positioning text annotation using transforms
fig, ax = plt.subplots()
ax.axis([0, 10, 0, 10])

ax.text(1, 5, ". Data:(1, 5)", transform=ax.transData ) #data coordinates
ax.text(0.5, 0.1, ". Axes:(0.5, 0.1)", transform=ax.transAxes ) #axes coordinates
ax.text(0.2, 0.2, ". Figure:(0.2, 0.2)", transform=fig.transFigure) #figure coordinates
# Out:
# Text(0.2, 0.2, '. Figure:(0.2, 0.2)')

# %%
# Annotate with arrow
fig, ax = plt.subplots(figsize=(5, 3))

ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')

ax.annotate('This is important!', xy=(10, 95), xytext=(20, 94),
 arrowprops=dict(facecolor='black', arrowstyle='fancy'))
# Out:
# Text(20, 94, 'This is important!')

# %%
# Removing tick marks and labels

# using formatters
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')


#ax.yaxis.set_major_locator(plt.NullLocator()) #removes y-axis labels
#ax.xaxis.set_major_formatter(plt.NullFormatter()) #removes x-axis labels

#ax.xaxis.set_major_locator(plt.MaxNLocator(3)) #sets max number of x-axis labels to 3

#ax.xaxis.set_major_locator(plt.MultipleLocator(5)) #sets x-axis labels at multiples of 5

#rotate axis labels
#plt.xticks(rotation=45, ha='right', fontsize=12, fontdict =font1)

# Set font properties/dictrionary
font1 = {' family':'serif','color':'indigo'}


plt.xticks(rotation=45, ha='right', fontsize=12, fontdict =font1) #rotate axis labels
plt.xlabel('Shiny New X Axis!', fontsize = 18, fontdict = font1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[53], line 6
#       4 fig, ax = plt.subplots(figsize=(5, 3))
#       5 ax.scatter(x,y1, label = "Person 1")
# ----> 6 ax.scatter(x,y2, label = "Person 2")
#       7 ax.legend(loc='lower right')
#      10 #ax.yaxis.set_major_locator(plt.NullLocator()) #removes y-axis labels
#      11 #ax.xaxis.set_major_formatter(plt.NullFormatter()) #removes x-axis labels
#      12
#    (...)     19
#      20 # Set font properties/dictrionary
#
# File c:\Users\Localadmin\miniconda3\envs\dsi_participant\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File c:\Users\Localadmin\miniconda3\envs\dsi_participant\Lib\site-packages\matplotlib\__init__.py:1521, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1518 @functools.wraps(func)
#    1519 def inner(ax, *args, data=None, **kwargs):
#    1520     if data is None:
# -> 1521         return func(
#    1522             ax,
#    1523             *map(cbook.sanitize_sequence, args),
#    1524             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1526     bound = new_sig.bind(ax, *args, **kwargs)
#    1527     auto_label = (bound.arguments.get(label_namer)
#    1528                   or bound.kwargs.get(label_namer))
#
# File c:\Users\Localadmin\miniconda3\envs\dsi_participant\Lib\site-packages\matplotlib\axes\_axes.py:4900, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, colorizer, plotnonfinite, **kwargs)
#    4898 y = np.ma.ravel(y)
#    4899 if x.size != y.size:
# -> 4900     raise ValueError("x and y must be the same size")
#    4902 if s is None:
#    4903     s = (20 if mpl.rcParams['_internal.classic_mode'] else
#    4904          mpl.rcParams['lines.markersize'] ** 2.0)
#
# ValueError: x and y must be the same size

# %%
# Applying styles
plt.style.use('default')

np.random.seed(613)

x = np.arange(50)
y1 = np.random.randint(0, 100,50)
y2 = np.random.randint(0, 100,50)

fig, ax = plt.subplots(figsize=(5, 3))

ax.plot(x,y2)

# %%
# to get a list of all available styles
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %% [markdown]
# ## Subplots and Combining Visualizations

# %%
x1 = np.arange(50)
y1 = np.random.randint(0, 75,50)
x2 = np.array(["Luffy", "Zoro", "Nami", "Usopp", "Sanji"])
y2 = np.array([110, 180, 240, 99, 220])

# %%
# to have two plots next to each other
fig, (ax1, ax2) = plt.subplots(ncols=2, 
                               nrows=1,
                               figsize=(7, 3))

ax1.scatter(x1,y1, color='green')
ax2.bar(x2,y2, color='orange')

#dictionary with properties we want for our labels
font1 = {'family':'sans-serif','color':'black','size':10}
    
#plot labels and titles
ax1.set_title('Scatterplot', fontdict = font1)
ax2.set_title('Bar graph', fontdict = font1)
# Out:
# Text(0.5, 1.0, 'Bar graph')

# %%
# Subplots without grid arrangement (someaxes is just a group we have named for axes/graph)
fig, someaxes = plt.subplot_mosaic([['ax1', 'ax3'],
                                     ['ax2', 'ax3']],
                                     figsize=(7, 4),
                                     layout='constrained' #automatically adjusts subplot parameters to give specified padding
                                     )

someaxes["ax1"].scatter(x1,y1, color='purple')
someaxes["ax2"].bar(x2,y2, color='green')
someaxes["ax3"].plot(x1,y1, color='orange')

someaxes["ax1"].set_xlabel('A Big Label',fontsize=18)
someaxes["ax2"].set_xlabel('Another Label',fontsize=18)
someaxes["ax3"].set_xlabel('Label 2: 2 Fast 2 Furious',fontsize=18 )
# Out:
# Text(0.5, 0, 'Label 2: 2 Fast 2 Furious')

# %%
# Multiple viz on one axes object

# first make our sample data
x = np.array(["Luffy", "Zoro", "Nami", "Usopp", "Sanji"])
y1 = np.array([110, 180, 240, 99, 220])
y2 = np.array([170, 100, 90, 120, 50])

# define our figure and axes (just one this time)
fig, ax = plt.subplots(figsize=(7, 3))

# now call both bar and plot elements to the same axes (ax)
ax.bar(x, y1,
      color = "indigo")
ax.plot(x, y2,
      color = "red")

# %%
# calculate standard deviation of our data
y2_sd = np.std(y2)

# plot our line as before
fig, ax = plt.subplots(figsize=(7, 3))
ax.plot(x, y2, color = "red")

# add error information
ax.errorbar(x, #our x values
            y2, #our y values
            yerr = y2_sd, # standard deviation
            fmt = "none",  # format - "none" means no marker
            ecolor = "indigo", #error bar colour
            elinewidth = 4, #error bar line width
            capsize = 6, #size of the cap on the error bar
            capthick = 4, #thickness of the cap
            errorevery=2 #plot error bar on every 2nd point
)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
# using images from internet

from PIL import Image # to open images
import requests # to get images from URLs
from io import BytesIO # to store images

# %%
# getting image from internet
response = requests.get('https://static.wikia.nocookie.net/the-ultimate-good/images/3/3d/Luffy.png/revision/latest?cb=20230417200546')
image_file = BytesIO(response.content)
image = Image.open(image_file)

# %%
# make basic line plot
fig, ax = plt.subplots(figsize=(7, 3))
ax.plot(x, y2, color = "red")

# overlay a new axis (‘ax_image’) on our figure (on top of ‘ax’) to act as a containerfor our image

ax_image = fig.add_axes([0.1, # x coordinate (ON FIGURE, NOT AXES)
                         0.11, # y coordinate (ON FIGURE, NOT AXES)
                         0.15, # image width
                         0.35] # image height)
        )
ax_image.imshow(image)
ax_image.axis('off') #turn off axis for image
# Out:
# (np.float64(-0.5), np.float64(410.5), np.float64(999.5), np.float64(-0.5))
